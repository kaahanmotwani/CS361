# %%
from scipy.io import arff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Question 1

# %%
min_dev_set = [5, 5, 5, 3, 2]
np.std(min_dev_set
# Out:
# 1.2649110640673518

# %%
max_dev_set = [10, 5, 5, 0, 0]
np.std(max_dev_set)
# Out:
# 3.7416573867739413

# %% [markdown]
# # Question 3

# %%
data = arff.loadarff('NuclearPlants.arff')
df = pd.DataFrame(data[0])

# %%
df
# Out:
#       Cost  MWatts   Date
# 0   345.39   514.0  67.92
# 1   460.05   687.0  68.58
# 2   452.99  1065.0  67.33
# 3   443.22  1065.0  67.33
# 4   652.32  1065.0  68.00
# 5   642.23  1065.0  68.00
# 6   272.37   822.0  68.17
# 7   317.21   457.0  68.42
# 8   457.12   822.0  68.42
# 9   690.19   792.0  68.33
# 10  350.63   560.0  68.58
# 11  402.59   790.0  68.75
# 12  412.18   530.0  68.42
# 13  495.58  1050.0  68.92
# 14  394.36   850.0  68.92
# 15  423.32   778.0  68.42
# 16  712.27   845.0  69.50
# 17  289.66   530.0  68.42
# 18  881.24  1090.0  69.17
# 19  490.88  1050.0  68.92
# 20  567.79   913.0  68.75
# 21  665.99   828.0  70.92
# 22  621.45   786.0  69.67
# 23  608.80   821.0  70.08
# 24  473.64   538.0  70.42
# 25  697.14  1130.0  71.08
# 26  207.51   745.0  67.25
# 27  288.48   821.0  67.17
# 28  284.88   886.0  67.83
# 29  280.36   886.0  67.83
# 30  217.38   745.0  67.25
# 31  270.71   886.0  67.83

# %%
df["Cost"].mean()
# Out:
# 461.5603124999999

# %%
(df["Cost"]/df["MWatts"]).mean()
# Out:
# 0.569735439641486

# %%
x_multi = df["Cost"]/df["MWatts"]
hist = (df["Cost"]/df["MWatts"]).hist(bins=10)

# %% [markdown]
# # Question 4

# %%
df = pd.read_csv('hotdogs.csv', header=None)
df.columns = ["Type", "Calories", "Sodium", "CUnused"]
del df['CUnused']
df
# Out:
#        Type  Calories  Sodium
# 0      Beef       186     495
# 1      Beef       181     477
# 2      Beef       176     425
# 3      Beef       149     322
# 4      Beef       184     482
# 5      Beef       190     587
# 6      Beef       158     370
# 7      Beef       139     322
# 8      Beef       175     479
# 9      Beef       148     375
# 10     Beef       152     330
# 11     Beef       111     300
# 12     Beef       141     386
# 13     Beef       153     401
# 14     Beef       190     645
# 15     Beef       157     440
# 16     Beef       131     317
# 17     Beef       149     319
# 18     Beef       135     298
# 19     Beef       132     253
# 20     Meat       173     458
# 21     Meat       191     506
# 22     Meat       182     473
# 23     Meat       190     545
# 24     Meat       172     496
# 25     Meat       147     360
# 26     Meat       146     387
# 27     Meat       139     386
# 28     Meat       175     507
# 29     Meat       136     393
# 30     Meat       179     405
# 31     Meat       153     372
# 32     Meat       107     144
# 33     Meat       195     511
# 34     Meat       135     405
# 35     Meat       140     428
# 36     Meat       138     339
# 37  Poultry       129     430
# 38  Poultry       132     375
# 39  Poultry       102     396
# 40  Poultry       106     383
# 41  Poultry        94     387
# 42  Poultry       102     542
# 43  Poultry        87     359
# 44  Poultry        99     357
# 45  Poultry       107     528
# 46  Poultry       113     513
# 47  Poultry       135     426
# 48  Poultry       142     513
# 49  Poultry        86     358
# 50  Poultry       143     581
# 51  Poultry       152     588
# 52  Poultry       146     522
# 53  Poultry       144     545
